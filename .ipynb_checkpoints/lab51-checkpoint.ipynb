# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
energy = pd.read_excel("En_In.xls")

# %%
energy.head(50)

energy = energy.drop(range(244, 282))
energy = energy.drop(range(17))
energy = energy.drop(columns=["Unnamed: 0", "Unnamed: 1"])
energy.columns = ["Country", "Energy Supply", "Energy Supply per Capita", "% Renewable"]

# %%
energy
# Out:
#                        Country Energy Supply Energy Supply per Capita  \
# 17                 Afghanistan           321                       10
# 18                     Albania           102                       35
# 19                     Algeria          1959                       51
# 20              American Samoa           ...                      ...
# 21                     Andorra             9                      121
# ..                         ...           ...                      ...
# 239                   Viet Nam          2554                       28
# 240  Wallis and Futuna Islands             0                       26
# 241                      Yemen           344                       13
# 242                     Zambia           400                       26
# 243                   Zimbabwe           480                       32
#
#     % Renewable
# 17      78.6693
# 18          100
# 19      0.55101
# 20     0.641026
# 21      88.6957
# ..          ...
# 239     45.3215
# 240           0
# 241           0
# 242     99.7147
# 243     52.5361
#
# [227 rows x 4 columns]

# %%
energy = energy.replace(["..."], np.NaN)

# %%
energy
# Out:
#                        Country  Energy Supply  Energy Supply per Capita  \
# 17                 Afghanistan          321.0                      10.0
# 18                     Albania          102.0                      35.0
# 19                     Algeria         1959.0                      51.0
# 20              American Samoa            NaN                       NaN
# 21                     Andorra            9.0                     121.0
# ..                         ...            ...                       ...
# 239                   Viet Nam         2554.0                      28.0
# 240  Wallis and Futuna Islands            0.0                      26.0
# 241                      Yemen          344.0                      13.0
# 242                     Zambia          400.0                      26.0
# 243                   Zimbabwe          480.0                      32.0
#
#      % Renewable
# 17     78.669280
# 18    100.000000
# 19      0.551010
# 20      0.641026
# 21     88.695650
# ..           ...
# 239    45.321520
# 240     0.000000
# 241     0.000000
# 242    99.714670
# 243    52.536120
#
# [227 rows x 4 columns]

# %%
energy["Energy Supply"] = energy["Energy Supply"].apply(lambda x: x * 1000000)

# %%
energy
# Out:
#                        Country  Energy Supply  Energy Supply per Capita  \
# 17                 Afghanistan   3.210000e+08                      10.0
# 18                     Albania   1.020000e+08                      35.0
# 19                     Algeria   1.959000e+09                      51.0
# 20              American Samoa            NaN                       NaN
# 21                     Andorra   9.000000e+06                     121.0
# ..                         ...            ...                       ...
# 239                   Viet Nam   2.554000e+09                      28.0
# 240  Wallis and Futuna Islands   0.000000e+00                      26.0
# 241                      Yemen   3.440000e+08                      13.0
# 242                     Zambia   4.000000e+08                      26.0
# 243                   Zimbabwe   4.800000e+08                      32.0
#
#      % Renewable
# 17     78.669280
# 18    100.000000
# 19      0.551010
# 20      0.641026
# 21     88.695650
# ..           ...
# 239    45.321520
# 240     0.000000
# 241     0.000000
# 242    99.714670
# 243    52.536120
#
# [227 rows x 4 columns]

# %%
energy["Country"] = energy["Country"].replace(["Republic of Korea"], "South Korea")

# %%
energy["Country"] = energy["Country"].replace(["China, Hong Kong Special Administrative Region"], "Hong Kong")

# %%
def check_str(x):
    res = []
    for i in range(len(x)):
            if x[i].isdigit():
                pass
            elif x[i] == "(":
                break
            else:
                res.append(x[i])
    return "".join(res).rstrip()

energy["Country"] = energy["Country"].apply(lambda x: check_str(x))

# %%
energy["Country"] = energy["Country"].replace("United States of America", "United States")
energy["Country"] = energy["Country"].replace("United Kingdom of Great Britain and Northern Ireland", "United Kingdom")
energy.loc[energy["Country"].isin(["American Samoa", "South Korea", "Bolivia", "United States"])]
# Out:
#             Country  Energy Supply  Energy Supply per Capita  % Renewable
# 20   American Samoa            NaN                       NaN     0.641026
# 41          Bolivia   3.360000e+08                      32.0    31.477120
# 181     South Korea   1.100700e+10                     221.0     2.279353
# 233   United States   9.083800e+10                     286.0    11.570980

# %%
energy.tail(50)
# Out:
#                                        Country  Energy Supply  \
# 194                               Saudi Arabia   7.985000e+09
# 195                                    Senegal   1.540000e+08
# 196                                     Serbia   6.180000e+08
# 197                                 Seychelles   9.000000e+06
# 198                               Sierra Leone   6.700000e+07
# 199                                  Singapore   1.120000e+09
# 200                               Sint Maarten   1.200000e+07
# 201                                   Slovakia   7.110000e+08
# 202                                   Slovenia   2.870000e+08
# 203                            Solomon Islands   6.000000e+06
# 204                                    Somalia   1.260000e+08
# 205                               South Africa   6.341000e+09
# 206                                South Sudan   2.800000e+07
# 207                                      Spain   4.923000e+09
# 208                                  Sri Lanka   3.880000e+08
# 209                         State of Palestine   6.100000e+07
# 210                                      Sudan   6.080000e+08
# 211                                   Suriname   3.400000e+07
# 212                                  Swaziland   4.900000e+07
# 213                                     Sweden   2.044000e+09
# 214                                Switzerland   1.113000e+09
# 215                       Syrian Arab Republic   5.420000e+08
# 216                                 Tajikistan   1.060000e+08
# 217                                   Thailand   5.336000e+09
# 218  The former Yugoslav Republic of Macedonia   1.170000e+08
# 219                                Timor-Leste   7.000000e+06
# 220                                       Togo   1.340000e+08
# 221                                      Tonga   3.000000e+06
# 222                        Trinidad and Tobago   8.240000e+08
# 223                                    Tunisia   4.300000e+08
# 224                                     Turkey   4.897000e+09
# 225                               Turkmenistan   1.102000e+09
# 226                   Turks and Caicos Islands   3.000000e+06
# 227                                     Tuvalu            NaN
# 228                                     Uganda   4.520000e+08
# 229                                    Ukraine   4.844000e+09
# 230                       United Arab Emirates   2.710000e+09
# 231                             United Kingdom   7.920000e+09
# 232                United Republic of Tanzania   9.940000e+08
# 233                              United States   9.083800e+10
# 234               United States Virgin Islands            NaN
# 235                                    Uruguay   1.960000e+08
# 236                                 Uzbekistan   1.798000e+09
# 237                                    Vanuatu   3.000000e+06
# 238                                  Venezuela   2.871000e+09
# 239                                   Viet Nam   2.554000e+09
# 240                  Wallis and Futuna Islands   0.000000e+00
# 241                                      Yemen   3.440000e+08
# 242                                     Zambia   4.000000e+08
# 243                                   Zimbabwe   4.800000e+08
#
#      Energy Supply per Capita  % Renewable
# 194                     264.0     0.000352
# 195                      11.0     1.998237
# 196                      69.0    27.216190
# 197                      94.0     1.977401
# 198                      11.0    64.024390
# 199                     207.0     0.000000
# 200                     327.0     0.000000
# 201                     131.0    20.217120
# 202                     139.0    31.864240
# 203                      11.0     0.000000
# 204                      12.0     0.000000
# 205                     119.0     1.687019
# 206                       2.0     0.423729
# 207                     106.0    37.968590
# 208                      19.0    59.573230
# 209                      14.0     0.000000
# 210                      16.0    78.410480
# 211                      65.0    22.023810
# 212                      39.0    40.677970
# 213                     212.0    46.598460
# 214                     136.0    57.745480
# 215                      28.0    11.568270
# 216                      13.0    99.742920
# 217                      79.0     4.305189
# 218                      56.0    26.140470
# 219                       6.0     0.000000
# 220                      19.0    80.180180
# 221                      28.0     0.000000
# 222                     611.0     0.000000
# 223                      39.0     3.492547
# 224                      64.0    28.536690
# 225                     210.0     0.000000
# 226                      85.0     0.000000
# 227                       NaN     0.000000
# 228                      12.0    68.018180
# 229                     107.0     8.067312
# 230                     300.0     0.000000
# 231                     124.0    10.600470
# 232                      20.0    31.072840
# 233                     286.0    11.570980
# 234                       NaN     0.000000
# 235                      58.0    71.605040
# 236                      62.0    21.328410
# 237                      10.0    14.705880
# 238                      95.0    67.834520
# 239                      28.0    45.321520
# 240                      26.0     0.000000
# 241                      13.0     0.000000
# 242                      26.0    99.714670
# 243                      32.0    52.536120

# %%
gpd = pd.read_csv("gpd.csv")

# %%
headers = list(gpd.loc[3])
headers[0] = "Country"
for i in range(4, len(headers)):
    headers[i] = int(headers[i])
gpd.columns = headers
gpd = gpd.drop([0, 1, 2, 3])

# %%
gpd
# Out:
#               Country Country Code                            Indicator Name  \
# 4               Aruba          ABW  GDP at market prices (constant 2010 US$)
# 5             Andorra          AND  GDP at market prices (constant 2010 US$)
# 6         Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 7              Angola          AGO  GDP at market prices (constant 2010 US$)
# 8             Albania          ALB  GDP at market prices (constant 2010 US$)
# ..                ...          ...                                       ...
# 263       Yemen, Rep.          YEM  GDP at market prices (constant 2010 US$)
# 264      South Africa          ZAF  GDP at market prices (constant 2010 US$)
# 265  Congo, Dem. Rep.          COD  GDP at market prices (constant 2010 US$)
# 266            Zambia          ZMB  GDP at market prices (constant 2010 US$)
# 267          Zimbabwe          ZWE  GDP at market prices (constant 2010 US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 4    NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# 5    NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# 6    NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# 7    NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# 8    NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# ..              ...           ...           ...           ...           ...
# 263  NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# 264  NY.GDP.MKTP.KD  7.707081e+10  8.003449e+10  8.497844e+10  9.124438e+10
# 265  NY.GDP.MKTP.KD  1.508024e+10  1.344383e+10  1.629401e+10  1.714358e+10
# 266  NY.GDP.MKTP.KD  4.592975e+09  4.655503e+09  4.539542e+09  4.688093e+09
# 267  NY.GDP.MKTP.KD  3.338344e+09  3.549199e+09  3.600111e+09  3.824915e+09
#
#              1964          1965  ...          2006          2007  \
# 4             NaN           NaN  ...           NaN           NaN
# 5             NaN           NaN  ...  4.018196e+09  4.021331e+09
# 6             NaN           NaN  ...  1.030523e+10  1.172119e+10
# 7             NaN           NaN  ...  5.581103e+10  6.842044e+10
# 8             NaN           NaN  ...  9.771760e+09  1.034829e+10
# ..            ...           ...  ...           ...           ...
# 263           NaN           NaN  ...  2.672565e+10  2.761787e+10
# 264  9.848904e+10  1.072507e+11  ...  3.402852e+11  3.585261e+11
# 265  1.672524e+10  1.689205e+10  ...  1.650894e+10  1.754232e+10
# 266  5.260699e+09  6.136472e+09  ...  1.440569e+10  1.560892e+10
# 267  3.782605e+09  3.968352e+09  ...  1.006276e+10  9.695130e+09
#
#              2008          2009          2010          2011          2012  \
# 4             NaN           NaN  2.467704e+09           NaN           NaN
# 5    3.675728e+09  3.535389e+09  3.346317e+09  3.185605e+09  3.129538e+09
# 6    1.214448e+10  1.469733e+10  1.593680e+10  1.691113e+10  1.935220e+10
# 7    7.787420e+10  7.975320e+10  8.247091e+10  8.570262e+10  9.012096e+10
# 8    1.112752e+10  1.150029e+10  1.192695e+10  1.223109e+10  1.240477e+10
# ..            ...           ...           ...           ...           ...
# 263  2.872656e+10  2.991436e+10  3.090675e+10  2.624342e+10  2.689160e+10
# 264  3.699668e+11  3.642764e+11  3.753494e+11  3.874074e+11  3.960071e+11
# 265  1.863448e+10  1.916651e+10  2.052329e+10  2.193213e+10  2.350200e+10
# 266  1.682234e+10  1.837342e+10  2.026555e+10  2.140358e+10  2.302438e+10
# 267  7.982103e+09  8.459783e+09  9.422161e+09  1.054391e+10  1.165789e+10
#
#              2013          2014          2015
# 4             NaN           NaN           NaN
# 5    3.127550e+09           NaN           NaN
# 6    1.973134e+10  1.999032e+10  2.029415e+10
# 7    9.626143e+10  1.008863e+11  1.039106e+11
# 8    1.254247e+10  1.279331e+10  1.312082e+10
# ..            ...           ...           ...
# 263  2.800914e+10           NaN           NaN
# 264  4.047682e+11  4.110369e+11  4.163117e+11
# 265  2.550050e+10  2.778776e+10  2.970961e+10
# 266  2.420595e+10  2.542227e+10  2.624127e+10
# 267  1.218064e+10  1.264939e+10  1.278517e+10
#
# [264 rows x 60 columns]

# %%
gpd["Country"] = gpd["Country"].replace(["Korea, Rep."], "South Korea")
gpd["Country"] = gpd["Country"].replace(["Iran, Islamic Rep."], "Iran")
gpd["Country"] = gpd["Country"].replace(["Hong Kong SAR, China"], "Hong Kong")

# %%
gpd[gpd["Country"] == "Hong Kong"]
# Out:
#       Country Country Code                            Indicator Name  \
# 97  Hong Kong          HKG  GDP at market prices (constant 2010 US$)
#
#     Indicator Code  1960  1961  1962  1963  1964          1965  ...  \
# 97  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN  1.764691e+10  ...
#
#             2006          2007          2008          2009          2010  \
# 97  2.019164e+11  2.149698e+11  2.195440e+11  2.141452e+11  2.286377e+11
#
#             2011          2012          2013          2014          2015
# 97  2.396459e+11  2.437206e+11  2.512081e+11  2.577757e+11  2.638606e+11
#
# [1 rows x 60 columns]

# %%
sci = pd.read_excel("scimagojr.xlsx")
sci
# Out:
#      Rank             Country  Documents  Citable documents  Citations  \
# 0       1               China     127050             126767     597237
# 1       2       United States      96661              94747     792274
# 2       3               Japan      30504              30287     223024
# 3       4      United Kingdom      20944              20357     206091
# 4       5  Russian Federation      18534              18301      34266
# ..    ...                 ...        ...                ...        ...
# 186   187              Guyana          1                  1          0
# 187   188    Christmas Island          1                  1          0
# 188   189             Reunion          1                  1          2
# 189   190         Saint Lucia          1                  1          0
# 190   191          Mauritania          1                  1          1
#
#      Self-citations  Citations per document  H index
# 0            411683                    4.70      138
# 1            265436                    8.20      230
# 2             61554                    7.31      134
# 3             37874                    9.84      139
# 4             12422                    1.85       57
# ..              ...                     ...      ...
# 186               0                    0.00        0
# 187               0                    0.00        0
# 188               1                    2.00        1
# 189               0                    0.00        0
# 190               0                    1.00        1
#
# [191 rows x 8 columns]

# %%
df = pd.merge(sci, energy, how="left", on="Country")

# %%
df = pd.merge(df, gpd, how="left", on="Country")

# %%
df = df.set_index("Country")
df = df.astype({"Rank": int})
columns_to_drop = [x for x in range(1960, 2006)]
df = df.drop(columns=columns_to_drop)
df = df.drop(columns=["Country Code", "Indicator Code", "Indicator Name"])

# %%
df.columns
# Out:
# Index([                    'Rank',                'Documents',
#               'Citable documents',                'Citations',
#                  'Self-citations',   'Citations per document',
#                         'H index',            'Energy Supply',
#        'Energy Supply per Capita',              '% Renewable',
#                              2006,                       2007,
#                              2008,                       2009,
#                              2010,                       2011,
#                              2012,                       2013,
#                              2014,                       2015],
#       dtype='object')

# %%
df = df[:15]

# %%
df
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# Australia             14       8831               8725      90765
# Brazil                15       8668               8596      60702
#
#                     Self-citations  Citations per document  H index  \
# Country
# China                       411683                    4.70      138
# United States               265436                    8.20      230
# Japan                        61554                    7.31      134
# United Kingdom               37874                    9.84      139
# Russian Federation           12422                    1.85       57
# Canada                       40930                   12.01      149
# Germany                      27426                    8.26      126
# India                        37209                    8.58      115
# France                       28601                    9.93      114
# South Korea                  22595                    9.57      104
# Italy                        26661                   10.20      106
# Spain                        23964                   13.08      115
# Iran                         19125                    6.46       72
# Australia                    15606                   10.28      107
# Brazil                       14396                    7.00       86
#
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# China                1.271910e+11                      93.0    19.754910
# United States        9.083800e+10                     286.0    11.570980
# Japan                1.898400e+10                     149.0    10.232820
# United Kingdom       7.920000e+09                     124.0    10.600470
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# France               1.059700e+10                     166.0    17.020280
# South Korea          1.100700e+10                     221.0     2.279353
# Italy                6.530000e+09                     109.0    33.667230
# Spain                4.923000e+09                     106.0    37.968590
# Iran                 9.172000e+09                     119.0     5.707721
# Australia            5.386000e+09                     231.0    11.810810
# Brazil               1.214900e+10                      59.0    69.648030
#
#                             2006          2007          2008          2009  \
# Country
# China               3.992331e+12  4.559041e+12  4.997775e+12  5.459247e+12
# United States       1.479230e+13  1.505540e+13  1.501149e+13  1.459484e+13
# Japan               5.496542e+12  5.617036e+12  5.558527e+12  5.251308e+12
# United Kingdom      2.419631e+12  2.482203e+12  2.470614e+12  2.367048e+12
# Russian Federation  1.385793e+12  1.504071e+12  1.583004e+12  1.459199e+12
# Canada              1.564469e+12  1.596740e+12  1.612713e+12  1.565145e+12
# Germany             3.332891e+12  3.441561e+12  3.478809e+12  3.283340e+12
# India               1.265894e+12  1.374865e+12  1.428361e+12  1.549483e+12
# France              2.607840e+12  2.669424e+12  2.674637e+12  2.595967e+12
# South Korea         9.410199e+11  9.924316e+11  1.020510e+12  1.027730e+12
# Italy               2.202170e+12  2.234627e+12  2.211154e+12  2.089938e+12
# Spain               1.414823e+12  1.468146e+12  1.484530e+12  1.431475e+12
# Iran                3.895523e+11  4.250646e+11  4.289909e+11  4.389208e+11
# Australia           1.021939e+12  1.060340e+12  1.099644e+12  1.119654e+12
# Brazil              1.845080e+12  1.957118e+12  2.056809e+12  2.054215e+12
#
#                             2010          2011          2012          2013  \
# Country
# China               6.039659e+12  6.612490e+12  7.124978e+12  7.672448e+12
# United States       1.496437e+13  1.520402e+13  1.554216e+13  1.577367e+13
# Japan               5.498718e+12  5.473738e+12  5.569102e+12  5.644659e+12
# United Kingdom      2.403504e+12  2.450911e+12  2.479809e+12  2.533370e+12
# Russian Federation  1.524917e+12  1.589943e+12  1.645876e+12  1.666934e+12
# Canada              1.613406e+12  1.664087e+12  1.693133e+12  1.730688e+12
# Germany             3.417298e+12  3.542371e+12  3.556724e+12  3.567317e+12
# India               1.708459e+12  1.821872e+12  1.924235e+12  2.051982e+12
# France              2.646995e+12  2.702032e+12  2.706968e+12  2.722567e+12
# South Korea         1.094499e+12  1.134796e+12  1.160809e+12  1.194429e+12
# Italy               2.125185e+12  2.137439e+12  2.077184e+12  2.040871e+12
# Spain               1.431673e+12  1.417355e+12  1.380216e+12  1.357139e+12
# Iran                4.677902e+11  4.853309e+11  4.532569e+11  4.445926e+11
# Australia           1.142251e+12  1.169431e+12  1.211913e+12  1.241484e+12
# Brazil              2.208872e+12  2.295245e+12  2.339209e+12  2.409740e+12
#
#                             2014          2015
# Country
# China               8.230121e+12  8.797999e+12
# United States       1.615662e+13  1.654857e+13
# Japan               5.642884e+12  5.669563e+12
# United Kingdom      2.605643e+12  2.666333e+12
# Russian Federation  1.678709e+12  1.616149e+12
# Canada              1.773486e+12  1.792609e+12
# Germany             3.624386e+12  3.685556e+12
# India               2.200617e+12  2.367206e+12
# France              2.729632e+12  2.761185e+12
# South Korea         1.234340e+12  1.266580e+12
# Italy               2.033868e+12  2.049316e+12
# Spain               1.375605e+12  1.419821e+12
# Iran                4.639027e+11           NaN
# Australia           1.272520e+12  1.301251e+12
# Brazil              2.412231e+12  2.319423e+12

# %%
df.shape
# Out:
# (15, 20)

# %%
years = (x for x in range(2006, 2016))
def task8():
    df["mean"] = df[years].mean(axis=1, skipna=True)
    return df["mean"].sort_values(ascending=False)
print(task8())
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  4.441558e+11
# Name: mean, dtype: float64

# %%
def task9():
    res = list(df.sort_values("mean", ascending=False).index.values)[4]
    return (res, df.loc[res][2015] - df.loc[res][2006])
print(task9())
df.drop(["mean"])
# Out:
# ('France', 153345695364.24023)

# %%
def task10():
    res = list(df.sort_values("% Renewable", ascending=False).index.values)[0]
    return(res, df.loc[res]["% Renewable"])
print(task10())
# Out:
# ('Brazil', 69.64803)

# %%
def task11():
    df["Population"] = df["Energy Supply"] / df["Energy Supply per Capita"]
    df
    res = list(df["Population"].sort_values(ascending=False).index.values)[5]
    return (res, df.loc[res]["Population"])
print(task11())
# Out:
# ('Japan', 127409395.97315437)

# %%
def task12():
    df["CitPerCap"] =  df["Citable documents"] / df["Population"]
    return df["Energy Supply per Capita"].corr(df['CitPerCap'], method="pearson")
print(task12())
# Out:
# 0.7940010435442947

# %%
def task13():
    temp = df["% Renewable"].median(axis=0)
    df["renew"] = df.apply(lambda x: 1 if x["% Renewable"] >= temp else 0, axis=1)
    df.sort_values(by='Rank')
    return df["renew"]
task13()
# Out:
# Country
# China                 1
# United States         0
# Japan                 0
# United Kingdom        0
# Russian Federation    1
# Canada                1
# Germany               1
# India                 0
# France                1
# South Korea           0
# Italy                 1
# Spain                 1
# Iran                  0
# Australia             0
# Brazil                1
# Name: renew, dtype: int64

# %%
def task14():
    ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}
    temp = pd.DataFrame(columns = ['size', 'sum', 'mean', 'std'])
    df['Population'] = df['Energy Supply'] / df['Energy Supply per Capita']
    for elem, val in df.groupby(ContinentDict):
        temp.loc[elem] = [len(val), val['Population'].sum(),val['Population'].mean(),val['Population'].std()]
    temp = temp.astype({"size":int})
    return temp
grouped = task14()
grouped
# Out:
#                size           sum          mean           std
# Asia              5  2.898666e+09  5.797333e+08  6.790979e+08
# Australia         1  2.331602e+07  2.331602e+07           NaN
# Europe            6  4.579297e+08  7.632161e+07  3.464767e+07
# North America     2  3.528552e+08  1.764276e+08  1.996696e+08
# South America     1  2.059153e+08  2.059153e+08           NaN

# %%
def task15():
    ContinentDict  = {'China':['Asia', "yellow"],
                  'United States':['North America', "red"],
                  'Japan':['Asia', "yellow"], 
                  'United Kingdom':['Europe', "blue"],
                  'Russian Federation':['Europe', "blue"],
                  'Canada':['North America', "red"],
                  'Germany':['Europe', "blue"],
                  'India':['Asia', "yellow"],
                  'France':['Europe', "blue"],
                  'South Korea':['Asia', "yellow"], 
                  'Italy':['Europe', "blue"],
                  'Spain':['Europe', "blue"],
                  'Iran':['Asia', "yellow"],
                  'Australia':['Australia', "green"],
                  'Brazil':['South America', "cyan"]}
    
    x, y, z = df["Rank"], df["% Renewable"], list(df.index.values)
    for i, text in enumerate(list(df.index)):
        plt.annotate(text, (x[i] - 0.3, y[i]))
    for elem in z:
        plt.scatter(x=x.loc[elem], y=y.loc[elem], s=df[2015][elem]/10000000000 * 3, alpha = 0.4, c = ContinentDict[elem][1])
    plt.xticks([i for i in range(0, len(list(df.index))+1)])
    plt.gcf().set_size_inches((15, 5))  
    plt.show()
task15()
