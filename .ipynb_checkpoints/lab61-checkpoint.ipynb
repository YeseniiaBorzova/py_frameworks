# %%
import pandas as pd

# %%
df = pd.read_csv("books.csv")

# %%
df
# Out:
#                             Title              Author       Genre  \
# 0        Fundamentals of Wavelets    Goswami, Jaideva        tech
# 1                      Data Smart       Foreman, John        tech
# 2        God Created the Integers    Hawking, Stephen        tech
# 3               Superfreakonomics     Dubner, Stephen     science
# 4                     Orientalism        Said, Edward  nonfiction
# ..                            ...                 ...         ...
# 206      Structure and Randomness        Tao, Terence     science
# 207  Image Processing with MATLAB       Eddins, Steve        tech
# 208                   Animal Farm      Orwell, George     fiction
# 209                    Idiot, The  Dostoevsky, Fyodor     fiction
# 210            Christmas Carol, A    Dickens, Charles     fiction
#
#               SubGenre  Height      Publisher  vowels
# 0    signal_processing     228          Wiley       4
# 1         data_science     235          Wiley       1
# ...

# %%
def task2():
    df["vowels"] = df["Author"].str.split(", ", expand=True)[1].str.count(r"[AEIOUaeiou]").fillna(0)
task2()
df = df.astype({'vowels': 'int32'})
df
# Out:
#                             Title              Author       Genre  \
# 0        Fundamentals of Wavelets    Goswami, Jaideva        tech
# 1                      Data Smart       Foreman, John        tech
# 2        God Created the Integers    Hawking, Stephen        tech
# 3               Superfreakonomics     Dubner, Stephen     science
# 4                     Orientalism        Said, Edward  nonfiction
# ..                            ...                 ...         ...
# 206      Structure and Randomness        Tao, Terence     science
# 207  Image Processing with MATLAB       Eddins, Steve        tech
# 208                   Animal Farm      Orwell, George     fiction
# 209                    Idiot, The  Dostoevsky, Fyodor     fiction
# 210            Christmas Carol, A    Dickens, Charles     fiction
#
#               SubGenre  Height      Publisher  vowels
# 0    signal_processing     228          Wiley       4
# 1         data_science     235          Wiley       1
# ...

# %%
def task3():
    return df[df["Author"].str.split(", ", expand=True)[0].str.contains(r"[AEIOUaeiou][AEIOUaeiou][AEIOUaeiou]", na=False)]
task3()
# Out:
#                                     Title   Author Genre   SubGenre  Height  \
# 75  Social Choice & Welfare, Vol 39 No. 1  Various  tech  economics     235
#
#    Publisher  vowels
# 75  Springer       0

# %%
def task4():
    return df[df["Title"].str.count(r"[, ]") == 0]
task4()
# Out:
#                  Title              Author       Genre       SubGenre  Height  \
# 3    Superfreakonomics     Dubner, Stephen     science      economics     179
# 4          Orientalism        Said, Edward  nonfiction        history     197
# 43        Freakonomics     Dubner, Stephen     science      economics     197
# 72              Scoop!       Nayar, Kuldip  nonfiction        history     216
# 79      Maqta-e-Ghalib        Garg, Sanjay  nonfiction         poetry     221
# 81              Manasa           Kale, V P  nonfiction           misc     213
# 117                One       Bach, Richard  nonfiction  autobiography     172
# 122             Apulki      Deshpande, P L  nonfiction           misc     211
# 140         Flashpoint                 NaN     fiction          comic     265
# 166             Mossad  Baz-Zohar, Michael  nonfiction        history     236
# 170         Hafasavnuk       Deshpande P L     fiction          novel     211
# ...

# %%
def task5():
    df["Number in title"] = df.apply(lambda x: 1 if  any(map(str.isdigit, x["Title"])) else 0, axis=1)
    return df["Number in title"]
task5()
df[df["Title"].str.contains(r"[0123456789]")]
# Out:
#                                         Title              Author    Genre  \
# 52                                   Catch 22      Heller, Joseph  fiction
# 75      Social Choice & Welfare, Vol 39 No. 1             Various     tech
# 105  Maugham's Collected Short Stories, Vol 3  Maugham, William S  fiction
# 143               Numbers Behind Numb3rs, The       Devlin, Keith  science
# 144                    Superman Earth One - 1                 NaN  fiction
# 145                    Superman Earth One - 2                 NaN  fiction
# 153        Journal of Economics, vol 106 No 3                 NaN  science
# 168               20000 Leagues Under the Sea        Verne, Jules  fiction
#
#         SubGenre  Height     Publisher  vowels  Number in title
# 52       classic     178  Random House       2                1
# 75     economics     235      Springer       0                1
# 105      classic     171       Vintage       3                1
# ...

# %%
df
# Out:
#                             Title              Author       Genre  \
# 0        Fundamentals of Wavelets    Goswami, Jaideva        tech
# 1                      Data Smart       Foreman, John        tech
# 2        God Created the Integers    Hawking, Stephen        tech
# 3               Superfreakonomics     Dubner, Stephen     science
# 4                     Orientalism        Said, Edward  nonfiction
# ..                            ...                 ...         ...
# 206      Structure and Randomness        Tao, Terence     science
# 207  Image Processing with MATLAB       Eddins, Steve        tech
# 208                   Animal Farm      Orwell, George     fiction
# 209                    Idiot, The  Dostoevsky, Fyodor     fiction
# 210            Christmas Carol, A    Dickens, Charles     fiction
#
#               SubGenre  Height      Publisher  vowels  Number in title
# 0    signal_processing     228          Wiley       4                0
# ...

# %%
def task6():
    df["Last word in book title"] = df.apply(lambda x: x["Title"].split(" ")[len(x["Title"].split(" ")) - 1], axis=1)
    return df["Last word in book title"]
task6()
# Out:
# 0               Wavelets
# 1                  Smart
# 2               Integers
# 3      Superfreakonomics
# 4            Orientalism
#              ...
# 206           Randomness
# 207               MATLAB
# 208                 Farm
# 209                  The
# 210                    A
# Name: Last word in book title, Length: 211, dtype: object

# %%
def task7():
    return df[df["Publisher"].str.count(r"[ ]") == 1]
task7()
# Out:
#                                                Title               Author  \
# 6                   Integration of the Indian States           Menon, V P
# 11                               Slaughterhouse Five       Vonnegut, Kurt
# 12                                Birth of a Theorem      Villani, Cedric
# 13   Structure & Interpretation of Computer Programs      Sussman, Gerald
# 15                                        Trial, The         Kafka, Frank
# 16                      Statistical Decision Theory'          Pratt, John
# 25                        Introduction to Algorithms       Cormen, Thomas
# 28             Complete Sherlock Holmes, The - Vol I  Doyle, Arthur Conan
# 29            Complete Sherlock Holmes, The - Vol II  Doyle, Arthur Conan
# 30                            Wealth of Nations, The          Smith, Adam
# 31                         Pillars of the Earth, The         Follett, Ken
# 34                   Surely You're Joking Mr Feynman     Feynman, Richard
# ...

# %%
def task8():
    return df[df["Author"].str.split(", ", expand=True)[0].str.match(r"..[y].*", na=False)]
task8()
# Out:
#                                       Title               Author       Genre  \
# 28    Complete Sherlock Holmes, The - Vol I  Doyle, Arthur Conan     fiction
# 29   Complete Sherlock Holmes, The - Vol II  Doyle, Arthur Conan     fiction
# 34          Surely You're Joking Mr Feynman     Feynman, Richard     science
# 72                                   Scoop!        Nayar, Kuldip  nonfiction
# 157                         Neural Networks        Haykin, Simon        tech
# 173           Cathedral and the Bazaar, The        Raymond, Eric        tech
#
#              SubGenre  Height      Publisher  vowels  Number in title  \
# 28            classic     176   Random House       4                0
# 29            classic     176   Random House       4                0
# 34            physics     198   Random House       2                0
# 72            history     216  HarperCollins       2                0
# 157      data_science     240            NaN       2                0
# ...
